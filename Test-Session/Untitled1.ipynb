# %%
# PANDAS 패키지 불러오기
import pandas as pd 
import pymysql 
from sqlalchemy import create_engine 
 
# DB 커넥션 열기
engine2 = create_engine('mysql+pymysql://haiteam:kopo1234!@192.168.110.107:1433/kopo') # localhost 는 본인 pc에 mysql이 설치된경우에만 가능

# DB 테이블을 읽어 Data Frame 변수에 저장하기
customerData = pd.read_sql_query('SELECT * FROM KOPO_PRODUCT_VOLUME ', engine2) 

# 컬럼해더 재정의
#customerData.columns = ['CUSTID1','AVGPRICE','EMI','DEVICECOUNT','PRODUCTAGE','CUSTTYPE']

# 데이터 VIEW
print(customerData)


# 데이터 저장
#resultname='mysqlresult_psj'
#customerData.to_sql(resultname, engine2, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     957                                 (self.host, self.port), self.connect_timeout,
# --> 958                                 **kwargs)
#     959                             break
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     723     if err is not None:
# --> 724         raise err
#     725     else:
#
# C:\ProgramData\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# ...
